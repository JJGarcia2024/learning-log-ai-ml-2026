# %%
import sys
# !{sys.executable} -m pip install google-cloud-bigquery
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-cloud-bigquery in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (3.41.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.30.3)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-cloud-bigquery) (2.53.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-cloud-bigquery) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-cloud-bigquery) (2.9.0)
# Requirement already satisfied: packaging>=24.2.0 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from google-cloud-bigquery) (26.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from google-cloud-bigquery) (2.33.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (6.33.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.28.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.80.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (48.0.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2026.4.22)
# Requirement already satisfied: cffi>=2.0.0 in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (2.0.0)
# Requirement already satisfied: pycparser in c:\ProgramData\anaconda3\envs\study_env\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\omniv\AppData\Roaming\Python\Python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.3)

# %%
from google.cloud import bigquery

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(

    r"G:\My Drive\Spacesmith and Wordsmith's Tower\Spacesmith's HQ\Nuclear Energy and Propulsion Engineering\Accenture AI-ML Computational Scientist\Credentials\gen-lang-client-0137385761-b0d89e37e8e5.json"

)

client = bigquery.Client(project="gen-lang-client-0137385761", credentials=credentials)

# %%
# Construct a reference to the "hacker_news" dataset
dataset_ref = client.dataset("hacker_news", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
# List all the tables in the "hacker_news" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset (there are four!)
for table in tables:  
    print(table.table_id)
# Out:
# full

# %%
# Construct a reference to the "full" table
table_ref = dataset_ref.table("full")

# API request - fetch the table
table = client.get_table(table_ref)

# %%
# Print information on all the columns in the "full" table in the "hacker_news" dataset
table.schema
# Out:
# [SchemaField('title', 'STRING', 'NULLABLE', None, 'Story title', (), None, None),
#  SchemaField('url', 'STRING', 'NULLABLE', None, 'Story url', (), None, None),
#  SchemaField('text', 'STRING', 'NULLABLE', None, 'Story or comment text', (), None, None),
#  SchemaField('dead', 'BOOLEAN', 'NULLABLE', None, 'Is dead?', (), None, None),
#  SchemaField('by', 'STRING', 'NULLABLE', None, "The username of the item's author.", (), None, None),
#  SchemaField('score', 'INTEGER', 'NULLABLE', None, 'Story score', (), None, None),
#  SchemaField('time', 'INTEGER', 'NULLABLE', None, 'Unix time', (), None, None),
#  SchemaField('timestamp', 'TIMESTAMP', 'NULLABLE', None, 'Timestamp for the unix time', (), None, None),
#  SchemaField('type', 'STRING', 'NULLABLE', None, 'type of details (comment comment_ranking poll story job pollopt)', (), None, None),
#  SchemaField('id', 'INTEGER', 'NULLABLE', None, "The item's unique id.", (), None, None),
#  SchemaField('parent', 'INTEGER', 'NULLABLE', None, 'Parent comment ID', (), None, None),
#  SchemaField('descendants', 'INTEGER', 'NULLABLE', None, 'Number of story or poll descendants', (), None, None),
#  SchemaField('ranking', 'INTEGER', 'NULLABLE', None, 'Comment ranking', (), None, None),
#  SchemaField('deleted', 'BOOLEAN', 'NULLABLE', None, 'Is deleted?', (), None, None)]

# %%
# Preview the first five lines of the "full" table
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#                                                title  \
# 0                              The Propulsion Papers
# 1  ClearTask: I built an AI app to cut your digit...
# 2  Ask HN: What skills are future proof in an AI ...
# 3                           Bcachefs 1.38.0 Released
# 4                     At Long Last, InfoWars Is Ours
#
#                                                  url  \
# 0  https://uniliterate.com/2026/03/part-iii-foren...
# 1        https://0d07b74677d946ca9e.v2.appdeploy.ai/
# 2                                               None
# 3  https://evilpiepirate.org/git/bcachefs-tools.g...
# 4                             https://theonion.info/
#
#                                                 text  dead              by  \
# 0                                               None  <NA>       jruohonen
# 1                                               None  <NA>         Girtino
# 2  For developers and non-developers alike: What&...  <NA>        sunny678
# 3                                               None  <NA>           d12bb
# 4                                               None  <NA>  throwaway81523
#
#    score        time                 timestamp   type        id  parent  \
# 0      1  1776750392 2026-04-21 05:46:32+00:00  story  47845024    <NA>
# 1      2  1776750527 2026-04-21 05:48:47+00:00  story  47845040    <NA>
# 2     46  1776750584 2026-04-21 05:49:44+00:00  story  47845050    <NA>
# 3      2  1776750617 2026-04-21 05:50:17+00:00  story  47845053    <NA>
# 4      4  1776750632 2026-04-21 05:50:32+00:00  story  47845056    <NA>
#
#    descendants  ranking  deleted
# 0            1     <NA>     <NA>
# 1            2     <NA>     <NA>
# 2           77     <NA>     <NA>
# 3            0     <NA>     <NA>
# 4            1     <NA>     <NA>
